# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\91950\Desktop\shopping_trends.csv')
data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
data.drop("Customer ID",inplace=True,axis=1)

# %%
data
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
data.drop_duplicates()
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
data.isna()
# Out:
#         Age  Gender  Item Purchased  Category  Purchase Amount (USD)  \
# 0     False   False           False     False                  False
# 1     False   False           False     False                  False
# 2     False   False           False     False                  False
# 3     False   False           False     False                  False
# 4     False   False           False     False                  False
# ...     ...     ...             ...       ...                    ...
# 3895  False   False           False     False                  False
# 3896  False   False           False     False                  False
# 3897  False   False           False     False                  False
# 3898  False   False           False     False                  False
# 3899  False   False           False     False                  False
#
#       Location   Size  Color  Season  Review Rating  Subscription Status  \
# ...

# %%
data.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
data.describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.068462              59.764359       3.749949           25.351538
# std      15.207589              23.685392       0.716223           14.447125
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              39.000000       3.100000           13.000000
# 50%      44.000000              60.000000       3.700000           25.000000
# 75%      57.000000              81.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3900 non-null   int64
#  1   Gender                    3900 non-null   object
#  2   Item Purchased            3900 non-null   object
#  3   Category                  3900 non-null   object
#  4   Purchase Amount (USD)     3900 non-null   int64
#  5   Location                  3900 non-null   object
#  6   Size                      3900 non-null   object
#  7   Color                     3900 non-null   object
#  8   Season                    3900 non-null   object
#  9   Review Rating             3900 non-null   float64
#  10  Subscription Status       3900 non-null   object
#  11  Payment Method            3900 non-null   object
#  12  Shipping Type             3900 non-null   object
# ...

# %%
data.drop("Discount Applied",axis=1,inplace=True)
data.drop("Preferred Payment Method",axis=1,inplace=True)
data.drop("Frequency of Purchases",axis=1,inplace=True)
data.drop("Promo Code Used",axis=1,inplace=True)

# %%
data
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
plt.figure(figsize=(14,10))
sns.countplot(x="Item Purchased",hue="Category",data=data)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x="Gender",data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
gender_count=data["Gender"].value_counts().reset_index()
gender_count
# Out:
#    Gender  count
# 0    Male   2652
# 1  Female   1248

# %%
Category_count=data["Category"].value_counts().reset_index()
Category_count
# Out:
#       Category  count
# 0     Clothing   1737
# 1  Accessories   1240
# 2     Footwear    599
# 3    Outerwear    324

# %%
Location_count=data["Location"].value_counts().reset_index()
Location_count
# Out:
#           Location  count
# 0          Montana     96
# 1       California     95
# 2            Idaho     93
# 3         Illinois     92
# 4          Alabama     89
# 5        Minnesota     88
# 6         Nebraska     87
# 7         New York     87
# 8           Nevada     87
# 9         Maryland     86
# 10        Delaware     86
# 11         Vermont     85
# 12       Louisiana     84
# 13    North Dakota     83
# 14        Missouri     81
# 15   West Virginia     81
# 16      New Mexico     81
# 17     Mississippi     80
# 18         Indiana     79
# 19         Georgia     79
# 20        Kentucky     79
# 21        Arkansas     79
# 22  North Carolina     78
# 23     Connecticut     78
# 24        Virginia     77
# 25            Ohio     77
# 26       Tennessee     77
# 27           Texas     77
# 28           Maine     77
# 29  South Carolina     76
# 30        Colorado     75
# 31        Oklahoma     75
# 32       Wisconsin     75
# 33          Oregon     74
# ...

# %%
columns=["Gender","Item Purchased","Category","Location","Size","Color","Season","Subscription Status","Payment Method","Shipping Type"]

# %%
for i in columns:
    plt.figure(figsize=(14,10))
    sns.countplot(x=i,data=data)
    plt.xticks(rotation=45)
    plt.show()
    plt.tight_layout()

# %%
for i in columns:
    print(f"{i} counts are:")
    final=pd.DataFrame(data[i].value_counts().reset_index())
    print(final)
    print()
    print()
# Out:
# Gender counts are:
#    Gender  count
# 0    Male   2652
# 1  Female   1248
#
#
# Item Purchased counts are:
#    Item Purchased  count
# 0          Blouse    171
# 1         Jewelry    171
# 2           Pants    171
# 3           Shirt    169
# 4           Dress    166
# 5         Sweater    164
# 6          Jacket    163
# 7            Belt    161
# 8      Sunglasses    161
# 9            Coat    161
# 10        Sandals    160
# 11          Socks    159
# 12          Skirt    158
# 13         Shorts    157
# 14          Scarf    157
# 15            Hat    154
# 16        Handbag    153
# 17         Hoodie    151
# 18          Shoes    150
# 19        T-shirt    147
# 20       Sneakers    145
# 21          Boots    144
# 22       Backpack    143
# 23         Gloves    140
# 24          Jeans    124
#
#
# Category counts are:
#       Category  count
# 0     Clothing   1737
# 1  Accessories   1240
# 2     Footwear    599
# 3    Outerwear    324
#
#
# Location counts are:
# ...

# %%
sns.countplot(x="Category",hue="Season",data=data)
plt.grid(color="black",linestyle="--")

# %%
data.groupby(["Category","Season"]).size().unstack()
# Out:
# Season       Fall  Spring  Summer  Winter
# Category
# Accessories   324     301     312     303
# Clothing      427     454     408     448
# Footwear      136     163     160     140
# Outerwear      88      81      75      80

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="Payment Method",hue="Season",data=data)
plt.xticks(rotation=30)
plt.grid(color="black",linestyle="--")
plt.gca().set_facecolor("lightblue")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="Shipping Type",hue="Category",data=data)
plt.xticks(rotation=30)
plt.grid(color="black",linestyle="--")
plt.gca().set_facecolor("lightyellow")
plt.show()

# %%
sns.countplot(x="Size",hue="Gender",data=data)
plt.xticks(rotation=30)
plt.grid(color="black",linestyle="--")
plt.gca().set_facecolor("lightyellow")
plt.show()

# %%
data.groupby(["Size","Gender"]).size().unstack()
# Out:
# Gender  Female  Male
# Size
# L          337   716
# M          590  1165
# S          187   476
# XL         134   295

# %%
plt.figure(figsize=(14,10))
sns.countplot(x="Payment Method",hue="Shipping Type",data=data)
plt.xticks(rotation=30)
plt.grid(color="black",linestyle="--")
plt.gca().set_facecolor("lightblue")
plt.show()

# %%
sns.countplot(x="Gender",hue="Subscription Status",data=data)
plt.xticks(rotation=30)
plt.grid(color="black",linestyle="--")
plt.gca().set_facecolor("lightblue")
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.countplot(x="Payment Method",hue="Category",data=data)
plt.xticks(rotation=30)
plt.grid(color="black",linestyle="--")
plt.gca().set_facecolor("lightblue")
plt.show()

# %%
mean_rating=data["Review Rating"].mean()
mean_rating
# Out:
# 3.7499487179487176

# %%
average_ratings_by_season = data.groupby("Season")["Review Rating"].mean()
average_ratings_by_season
# Out:
# Season
# Fall      3.729949
# Spring    3.790591
# Summer    3.725654
# Winter    3.752111
# Name: Review Rating, dtype: float64

# %%
average_amount=data.groupby("Payment Method")["Purchase Amount (USD)"].mean()
print("Average amount spend with respect to payment method",average_amount)
# Out:
# Average amount spend with respect to payment method Payment Method
# Bank Transfer    58.738924
# Cash             59.927469
# Credit Card      61.159483
# Debit Card       58.638231
# PayPal           58.697492
# Venmo            61.241960
# Name: Purchase Amount (USD), dtype: float64

# %%
average_wrt_gender=data.groupby("Gender")["Purchase Amount (USD)"].mean()
print("Averege amount spend with respect to the gender is",average_wrt_gender)
# Out:
# Averege amount spend with respect to the gender is Gender
# Female    60.249199
# Male      59.536199
# Name: Purchase Amount (USD), dtype: float64

# %%
INR_Average=average_wrt_gender*83
print("Averege amount spend with respect to the gender in INR is",round(INR_Average,3))
# Out:
# Averege amount spend with respect to the gender in INR is Gender
# Female    5000.683
# Male      4941.505
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.countplot(x="Payment Method",hue="Gender",data=data)
plt.xticks(rotation=35)
plt.grid(color="black",linestyle="--")
plt.show()

# %%
data.groupby("Gender")["Previous Purchases"].sum()
# Out:
# Gender
# Female    30696
# Male      68175
# Name: Previous Purchases, dtype: int64

# %%
cat_pur=pd.DataFrame(data.groupby("Category")["Previous Purchases"].sum())
cat_pur
# Out:
#              Previous Purchases
# Category
# Accessories               31900
# Clothing                  43771
# Footwear                  15114
# Outerwear                  8086

# %%
data["Size"].value_counts().reset_index()
# Out:
#   Size  count
# 0    M   1755
# 1    L   1053
# 2    S    663
# 3   XL    429

# %%
sns.countplot(x="Size",data=data)
# Out:
# <Axes: xlabel='Size', ylabel='count'>

# %%
data.groupby(["Size","Gender"]).size().unstack()
# Out:
# Gender  Female  Male
# Size
# L          337   716
# M          590  1165
# S          187   476
# XL         134   295

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    3900 non-null   int64
#  1   Gender                 3900 non-null   object
#  2   Item Purchased         3900 non-null   object
#  3   Category               3900 non-null   object
#  4   Purchase Amount (USD)  3900 non-null   int64
#  5   Location               3900 non-null   object
#  6   Size                   3900 non-null   object
#  7   Color                  3900 non-null   object
#  8   Season                 3900 non-null   object
#  9   Review Rating          3900 non-null   float64
#  10  Subscription Status    3900 non-null   object
#  11  Payment Method         3900 non-null   object
#  12  Shipping Type          3900 non-null   object
#  13  Previous Purchases     3900 non-null   int64
# dtypes: float64(1), int64(3), object(10)
# ...

# %%
data1=data[["Age","Purchase Amount (USD)","Review Rating","Previous Purchases"]]
data1
# Out:
#       Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# 0      55                     53            3.1                  14
# 1      19                     64            3.1                   2
# 2      50                     73            3.1                  23
# 3      21                     90            3.5                  49
# 4      45                     49            2.7                  31
# ...   ...                    ...            ...                 ...
# 3895   40                     28            4.2                  32
# 3896   52                     49            4.5                  41
# 3897   46                     33            2.9                  24
# 3898   44                     77            3.8                  24
# 3899   52                     81            3.1                  33
#
# [3900 rows x 4 columns]

# %%
data.describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.068462              59.764359       3.749949           25.351538
# std      15.207589              23.685392       0.716223           14.447125
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              39.000000       3.100000           13.000000
# 50%      44.000000              60.000000       3.700000           25.000000
# 75%      57.000000              81.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
correlation_matrix=data1.corr()
correlation_matrix
# Out:
#                             Age  Purchase Amount (USD)  Review Rating  \
# Age                    1.000000              -0.010424      -0.021949
# Purchase Amount (USD) -0.010424               1.000000       0.030776
# Review Rating         -0.021949               0.030776       1.000000
# Previous Purchases     0.040445               0.008063       0.004229
#
#                        Previous Purchases
# Age                              0.040445
# Purchase Amount (USD)            0.008063
# Review Rating                    0.004229
# Previous Purchases               1.000000

# %%
sns.heatmap(correlation_matrix,cmap="coolwarm",annot=True,  fmt=".2f", linewidths=.5)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(18, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap for Gender, Discount, Promo Code, and Subscription Status')
plt.show()

# %%
average_age_category=data.groupby("Category")["Age"].mean()
average_age_category
# Out:
# Category
# Accessories    44.224194
# Clothing       43.782959
# Footwear       44.442404
# Outerwear      44.311728
# Name: Age, dtype: float64

# %%
average_age_items=data.groupby("Item Purchased")["Age"].mean()
average_age_items
# Out:
# Item Purchased
# Backpack      42.895105
# Belt          42.440994
# Blouse        44.286550
# Boots         44.847222
# Coat          43.217391
# Dress         44.602410
# Gloves        43.071429
# Handbag       46.052288
# Hat           43.551948
# Hoodie        44.874172
# Jacket        45.392638
# Jeans         43.725806
# Jewelry       46.292398
# Pants         43.502924
# Sandals       44.156250
# Scarf         44.324841
# Shirt         41.994083
# Shoes         46.126667
# Shorts        43.420382
# Skirt         44.284810
# Sneakers      42.613793
# Socks         44.792453
# Sunglasses    44.801242
# Sweater       43.335366
# T-shirt       42.836735
# Name: Age, dtype: float64

# %%
data.groupby(["Color","Item Purchased"]).size().unstack()
# Out:
# Item Purchased  Backpack  Belt  Blouse  Boots  Coat  Dress  Gloves  Handbag  \
# Color
# Beige                  4     5       9      3     8      6       5        8
# Black                 11     3       4      3     8      8       4        6
# Blue                   7    12       5      6     8      5       6        7
# Brown                  4     4       8      7     6      4       2        7
# Charcoal               3    10       9      3     5     12       7       12
# Cyan                   7     7       5      7     8     11      10        7
# Gold                   7     6       4      3     5      9       6        6
# Gray                   9     7       8      6     8      6       5       10
# Green                  8     9       9      6     8      9       7        6
# Indigo                 5     7       5      7     4      5       6        3
# Lavender               5     8       9      6     8      6       1        6
# ...

# %%
data.groupby(["Color","Category"]).size().unstack()
# Out:
# Category   Accessories  Clothing  Footwear  Outerwear
# Color
# Beige               44        65        24         14
# Black               51        81        25         10
# Blue                59        49        25         19
# Brown               44        61        24         12
# Charcoal            55        73        15         10
# Cyan                47        76        27         16
# Gold                41        62        24         11
# Gray                59        62        23         15
# Green               53        78        24         14
# Indigo              52        59        25         11
# Lavender            49        60        22         16
# Magenta             58        59        22         13
# Maroon              41        83        26          8
# Olive               66        61        31         19
# Orange              44        78        24          8
# Peach               58        65        18          8
# ...

# %%
data
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
x=data.drop("Subscription Status",axis=1)
y=data["Subscription Status"]

# %%
x
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating Payment Method  \
# ...

# %%
y
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3895     No
# 3896     No
# 3897     No
# 3898     No
# 3899     No
# Name: Subscription Status, Length: 3900, dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
categorical_features=["Gender","Item Purchased","Category","Location","Size","Color","Season","Payment Method","Shipping Type"]

# %%
one_hot=OneHotEncoder()
transformer=ColumnTransformer([("one_hot",one_hot,categorical_features)],remainder="passthrough")
transformed_x=transformer.fit_transform(x)
pd.DataFrame(transformed_x)
# Out:
#                                                       0
# 0       (0, 1)\t1.0\n  (0, 4)\t1.0\n  (0, 28)\t1.0\n...
# 1       (0, 1)\t1.0\n  (0, 25)\t1.0\n  (0, 28)\t1.0\...
# 2       (0, 1)\t1.0\n  (0, 13)\t1.0\n  (0, 28)\t1.0\...
# 3       (0, 1)\t1.0\n  (0, 16)\t1.0\n  (0, 29)\t1.0\...
# 4       (0, 1)\t1.0\n  (0, 4)\t1.0\n  (0, 28)\t1.0\n...
# ...                                                 ...
# 3895    (0, 0)\t1.0\n  (0, 11)\t1.0\n  (0, 28)\t1.0\...
# 3896    (0, 0)\t1.0\n  (0, 2)\t1.0\n  (0, 27)\t1.0\n...
# 3897    (0, 0)\t1.0\n  (0, 3)\t1.0\n  (0, 27)\t1.0\n...
# 3898    (0, 0)\t1.0\n  (0, 19)\t1.0\n  (0, 29)\t1.0\...
# 3899    (0, 0)\t1.0\n  (0, 9)\t1.0\n  (0, 27)\t1.0\n...
#
# [3900 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
np.random.seed(42)
x_train,x_test,y_train,y_test=train_test_split(transformed_x,y,test_size=0.2)
model=LogisticRegression()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# C:\Users\91950\Desktop\sample_project1\env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6807692307692308

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(model,transformed_x,y,cv=10)
score
# Out:
# C:\Users\91950\Desktop\sample_project1\env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91950\Desktop\sample_project1\env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
final_score=score.mean()
print(f"The final score of the logistic regression is {final_score*100:.2f} %")
# Out:
# The final score of the logistic regression is 69.18 %

# %%
y_preds=model.predict(x_test)
y_preds[0:30]
# Out:
# array(['No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No'], dtype=object)

# %%
np.array(y_test)[0:30]
# Out:
# array(['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No',
#        'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No'],
#       dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier
new_model=RandomForestClassifier()
new_model.fit(x_train,y_train)
new_model.score(x_test,y_test)
# Out:
# 0.7038461538461539

# %%
score_new=cross_val_score(new_model,transformed_x,y,cv=10)
score_new
# Out:
# array([0.66923077, 0.65128205, 0.7025641 , 0.66666667, 0.68205128,
#        0.68461538, 0.74358974, 0.74358974, 0.74615385, 0.74358974])

# %%
final_score_classifier=score_new.mean()
print(f"The random forest Classifier score is {final_score_classifier*100:.2f} %")
# Out:
# The random forest Classifier score is 70.33 %
